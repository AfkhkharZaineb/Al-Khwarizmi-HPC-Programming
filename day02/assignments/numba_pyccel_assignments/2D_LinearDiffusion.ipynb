# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D
from numba import njit
from pyccel.epyccel import epyccel
import time

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu):
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    for n in range(nt + 1): 
        un = u.copy()
        u[1:-1, 1:-1] = (un[1:-1,1:-1] + 
                        nu * dt / dx**2 * 
                        (un[1:-1, 2:] - 2 * un[1:-1, 1:-1] + un[1:-1, 0:-2]) +
                        nu * dt / dy**2 * 
                        (un[2:,1: -1] - 2 * un[1:-1, 1:-1] + un[0:-2, 1:-1]))
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
        
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit
def solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu):
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    for n in range(nt + 1): 
        un = u.copy()
        u[1:-1, 1:-1] = (un[1:-1,1:-1] + 
                        nu * dt / dx**2 * 
                        (un[1:-1, 2:] - 2 * un[1:-1, 1:-1] + un[1:-1, 0:-2]) +
                        nu * dt / dy**2 * 
                        (un[2:,1: -1] - 2 * un[1:-1, 1:-1] + un[0:-2, 1:-1]))
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
        
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
def solve_2d_diff_pyccel(u : 'float[:]', un : 'float[:]', nt : int,dt : float, dx : float, dy : float, nu : float):
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    for n in range(nt + 1): 
        un = u.copy()
        u[1:-1, 1:-1] = (un[1:-1,1:-1] + 
                        nu * dt / dx**2 * 
                        (un[1:-1, 2:] - 2 * un[1:-1, 1:-1] + un[1:-1, 0:-2]) +
                        nu * dt / dy**2 * 
                        (un[2:,1: -1] - 2 * un[1:-1, 1:-1] + un[0:-2, 1:-1]))
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
        
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nt = 51
nx = 101
ny = 101
nu = .05
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx))  # create a 1xn vector of 1's
un = np.ones((ny, nx))
    

solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu)

fig = pyplot.figure(figsize=(11, 7), dpi=100)
ax = fig.gca(projection='3d')                      
X, Y = np.meshgrid(x, y)                            
surf = ax.plot_surface(X, Y, u, cmap=cm.viridis)
# Out:
# /home/zineb/Documents/Al-Khwarizmi-HPC-Programming/v_en/lib/python3.7/site-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu)
# Out:
# 8.89 ms ± 75.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu)
# Out:
# 4.76 ms ± 93.5 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)

# %%
# %timeit solve_2d_diff_f90(u, un, nt, dt, dx, dy, nu)
# Out:
# 868 µs ± 14.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
